# %%
import os
import numpy as np
import pickle

import xarray as xr
import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
cartopy.config['data_dir'] = os.getenv('CARTOPY_DIR', cartopy.config.get('data_dir'))

import cmocean

from matplotlib import pyplot as plt
#%config InlineBackend.figure_format = 'retina'
plt.ion()  # To trigger the interactive inline mode

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
# For the bio dataset
base_url = "https://thredds.ereefs.aims.gov.au/thredds/dodsC/s3://aims-ereefs-public-prod/derived/ncaggregate/ereefs/GBR4_H2p0_B3p1_Cq3b_Dhnd/monthly-monthly/EREEFS_AIMS-CSIRO_GBR4_H2p0_B3p1_Cq3b_Dhnd_bgc_monthly-monthly-"

# %%
month_st = 1   # Starting month 
month_ed = 1   # Ending month 
year_st = 2011    # Year
year_ed = 2011    # Year

# Based on the server the file naming convention 
biofiles = [f"{base_url}{year}-{month:02}.nc" for year in range(year_st, year_ed+1) for month in range(month_st, month_ed+1) ]

ds_bio_sample = xr.open_mfdataset(biofiles,use_cftime= True)
ds_bio_sample
# Out:
# <xarray.Dataset>
# Dimensions:          (time: 1, k: 17, latitude: 723, longitude: 491)
# Coordinates:
#     zc               (k) float64 dask.array<chunksize=(17,), meta=np.ndarray>
#   * time             (time) object 2010-12-31 14:00:00
#   * latitude         (latitude) float64 -28.7 -28.67 -28.64 ... -7.066 -7.036
#   * longitude        (longitude) float64 142.2 142.2 142.2 ... 156.8 156.8 156.9
# Dimensions without coordinates: k
# Data variables: (12/108)
#     TOTAL_NITROGEN   (time, k, latitude, longitude) float32 dask.array<chunksize=(1, 17, 723, 491), meta=np.ndarray>
#     alk              (time, k, latitude, longitude) float32 dask.array<chunksize=(1, 17, 723, 491), meta=np.ndarray>
#     BOD              (time, k, latitude, longitude) float32 dask.array<chunksize=(1, 17, 723, 491), meta=np.ndarray>
#     Chl_a_sum        (time, k, latitude, longitude) float32 dask.array<chunksize=(1, 17, 723, 491), meta=np.ndarray>
# ...

# %%
l=list(ds_bio_sample.data_vars)

# %%
print([' '.join([i.strip() for i in x.strip().split('\t')]) for x in l])
# Out:
# ['TOTAL_NITROGEN', 'alk', 'BOD', 'Chl_a_sum', 'CO32', 'DetBL_N', 'DetPL_N', 'DetR_N', 'DIC', 'DIN', 'DIP', 'DOR_C', 'DOR_N', 'DOR_P', 'Dust', 'EFI', 'FineSed', 'Fluorescence', 'HCO3', 'Kd_490', 'MPB_Chl', 'MPB_N', 'MPB_NR', 'Mud-carbonate', 'Mud-mineral', 'Nfix', 'NH4', 'NO3', 'omega_ar', 'Oxy_sat', 'Oxygen', 'P_Prod', 'PAR', 'PAR_z', 'pco2surf', 'PH', 'PhyL_Chl', 'PhyL_N', 'PhyL_NR', 'PhyS_Chl', 'PhyS_N', 'PhyS_NR', 'PIP', 'salt', 'TC', 'temp', 'TN', 'TP', 'Tricho_Chl', 'Tricho_N', 'Tricho_NR', 'Z_grazing', 'ZooL_N', 'ZooS_N', 'CH_N', 'CS_bleach', 'CS_Chl', 'CS_N', 'EpiPAR_sg', 'eta', 'MA_N', 'MA_N_pr', 'month_EpiPAR_sg', 'R_400', 'R_410', 'R_412', 'R_443', 'R_470', 'R_486', 'R_488', 'R_490', 'R_510', 'R_531', 'R_547', 'R_551', 'R_555', 'R_560', 'R_590', 'R_620', 'R_640', 'R_645', 'R_665', 'R_667', 'R_671', 'R_673', 'R_678', 'R_681', 'R_709', 'R_745', 'R_748', 'R_754', 'R_761', 'R_764', 'R_767', 'R_778', 'Secchi', 'SG_N', 'SG_N_pr', 'SG_shear_mort', 'SGD_N', 'SGD_N_pr', 'SGD_shear_m
# ...

# %%
month_st = 1   # Starting month 
month_ed = 12   # Ending month 
year_st = 2011    # Year
year_ed = 2011    # Year

# Based on the server the file naming convention 
biofiles = [f"{base_url}{year}-{month:02}.nc" for year in range(year_st, year_ed+1) for month in range(month_st, month_ed+1) ]

ds_bio11 = xr.open_mfdataset(biofiles,use_cftime= True)

# %%
ds_dpth11 = ds_bio11.sel(k=5)

ds_bio11_chl = ds_dpth11[['Chl_a_sum']]
ds_bio11_chl

# %%
ds_bio11_chl.to_netcdf("ds_bio11_chl.nc")

# %%
month_st = 1   # Starting month 
month_ed = 12   # Ending month 
year_st = 2012    # Year
year_ed = 2012    # Year

# Based on the server the file naming convention 
biofiles = [f"{base_url}{year}-{month:02}.nc" for year in range(year_st, year_ed+1) for month in range(month_st, month_ed+1) ]

ds_bio12 = xr.open_mfdataset(biofiles)

# %%
ds_dpth12 = ds_bio12.sel(k=5)

ds_bio12_chl = ds_dpth12[['Chl_a_sum']]
ds_bio12_chl

# %%
ds_bio12_chl.to_netcdf("ds_bio12_chl.nc")

# %%
month_st = 1   # Starting month 
month_ed = 12   # Ending month 
year_st = 2013    # Year
year_ed = 2013    # Year

# Based on the server the file naming convention 
biofiles = [f"{base_url}{year}-{month:02}.nc" for year in range(year_st, year_ed+1) for month in range(month_st, month_ed+1) ]

ds_bio13 = xr.open_mfdataset(biofiles)

# %%
ds_dpth13 = ds_bio13.sel(k=5)

ds_bio13_chl = ds_dpth13[['Chl_a_sum']]
ds_bio13_chl

# %%
ds_bio13_chl.to_netcdf("ds_bio13_chl.nc")

# %%
month_st = 1   # Starting month 
month_ed = 12   # Ending month 
year_st = 2014    # Year
year_ed = 2014    # Year

# Based on the server the file naming convention 
biofiles = [f"{base_url}{year}-{month:02}.nc" for year in range(year_st, year_ed+1) for month in range(month_st, month_ed+1) ]

ds_bio14 = xr.open_mfdataset(biofiles)

# %%
ds_dpth14 = ds_bio14.sel(k=5)

ds_bio14_chl = ds_dpth14[['Chl_a_sum']]

# %%
ds_bio14_chl.to_netcdf("ds_bio14_chl.nc")

# %%
month_st = 1   # Starting month 
month_ed = 12   # Ending month 
year_st = 2015    # Year
year_ed = 2015    # Year

# Based on the server the file naming convention 
biofiles = [f"{base_url}{year}-{month:02}.nc" for year in range(year_st, year_ed+1) for month in range(month_st, month_ed+1) ]

ds_bio15 = xr.open_mfdataset(biofiles)

# %%
ds_dpth15 = ds_bio15.sel(k=5)

ds_bio15_chl = ds_dpth15[['Chl_a_sum']]

# %%
ds_bio15_chl.to_netcdf("ds_bio15_chl.nc")

# %%
month_st = 1   # Starting month 
month_ed = 12   # Ending month 
year_st = 2016    # Year
year_ed = 2016    # Year

# Based on the server the file naming convention 
biofiles = [f"{base_url}{year}-{month:02}.nc" for year in range(year_st, year_ed+1) for month in range(month_st, month_ed+1) ]

ds_bio16 = xr.open_mfdataset(biofiles)

# %%
ds_dpth16= ds_bio16.sel(k=5)

ds_bio16_chl = ds_dpth16[['Chl_a_sum']]

# %%
ds_bio16_chl.to_netcdf("ds_bio16_chl.nc")

# %%
month_st = 1   # Starting month 
month_ed = 12   # Ending month 
year_st = 2017    # Year
year_ed = 2017    # Year

# Based on the server the file naming convention 
biofiles = [f"{base_url}{year}-{month:02}.nc" for year in range(year_st, year_ed+1) for month in range(month_st, month_ed+1) ]

ds_bio17 = xr.open_mfdataset(biofiles)

# %%
ds_dpth17= ds_bio17.sel(k=5)

ds_bio17_chl = ds_dpth17[['Chl_a_sum']]

# %%
ds_bio17_chl.to_netcdf("ds_bio17_chl.nc")

# %%
month_st = 1   # Starting month 
month_ed = 12   # Ending month 
year_st = 2018    # Year
year_ed = 2018    # Year

# Based on the server the file naming convention 
biofiles11 = [f"{base_url}{year}-{month:02}.nc" for year in range(year_st, year_ed+1) for month in range(month_st, month_ed+1) ]

ds_bio18 = xr.open_mfdataset(biofiles11)

# %%
ds_dpth18= ds_bio18.sel(k=5)

ds_bio18_chl = ds_dpth18[['Chl_a_sum']]

# %%
ds_bio18_chl.to_netcdf("ds_bio18_chl.nc")

# %%
ds_bio_chl = xr.open_mfdataset(["ds_bio11_chl.nc","ds_bio12_chl.nc","ds_bio13_chl.nc","ds_bio14_chl.nc","ds_bio15_chl.nc","ds_bio16_chl.nc",
                            "ds_bio17_chl.nc","ds_bio18_chl.nc"])
ds_bio_chl

# %%
ds_bio_chl.to_netcdf("ds_bio_chl.nc")

# %%
locA_lat = -27.405408
locA_lon = 153.783334

# %%
# Figure size
size = (9, 10)

# Color from cmocean
color = cmocean.cm.balance

# Defining the figure
fig = plt.figure(figsize=size, facecolor='w', edgecolor='k')

# Axes with Cartopy projection
ax = plt.axes(projection=ccrs.PlateCarree())
# and extent
ax.set_extent([142.4, 157, -7, -28.6], ccrs.PlateCarree())

# Plotting using Matplotlib 
# We plot the PH at the surface at the final recorded time interval
cf = ds_bio11_chl.Chl_a_sum.isel(time=-1,k=-1).plot( 
    transform=ccrs.PlateCarree(), cmap=color,
    vmin = 0, vmax = 1.4,
    add_colorbar=False
)

# Color bar
cbar = fig.colorbar(cf, ax=ax, fraction=0.027, pad=0.045, 
                    orientation="horizontal")
cbar.set_label(ds_bio11_chl.Chl_a_sum.long_name+' '+ds_bio11_chl.Chl_a_sum.units, rotation=0, 
               labelpad=5, fontsize=10)
cbar.ax.tick_params(labelsize=8)

# Title
plt.title('zc = '+str(ds_bio11_chl.zc.values.item(-1))+' m at '+str(ds_bio11_chl.coords['time'].values[-1])[:10],
          fontsize=11
         )

# Plot lat/lon grid 
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=0.1, color='k', alpha=1, 
                  linestyle='--')
gl.top_labels = False
gl.right_labels = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
gl.xlabel_style = {'size': 8}
gl.ylabel_style = {'size': 8} 

# Add map features with Cartopy 
ax.add_feature(cfeature.NaturalEarthFeature('physical', 'land', '10m', 
                                            edgecolor='face', 
                                            facecolor='lightgray'))
ax.coastlines(linewidth=1)

# Site Davies Reef
ax.scatter(locA_lon, locA_lat, c='deeppink', s=50, edgecolors='k', linewidth=1, transform=ccrs.PlateCarree())

plt.tight_layout()
plt.show()
# fig.clear()
# plt.close(fig)
# plt.clf()

# %%
min_lon = 152     # lower left longitude
min_lat = -29    # lower left latitude
max_lon = 158     # upper right longitude
max_lat = -24     # upper right latitude

# Defining the boundaries
lon_bnds = [min_lon, max_lon]
lat_bnds = [min_lat, max_lat]

# %%
# Performing the reduction 
ds_bio11_clip = ds_bio11.sel(latitude=slice(*lat_bnds), longitude=slice(*lon_bnds))
ds_bio11_clip.to_netcdf('region11.nc')

# %%
# Figure size
size = (9, 10)

# Color from cmocean
color = cmocean.cm.balance

# Defining the figure
fig = plt.figure(figsize=size, facecolor='w', edgecolor='k')

# Axes with Cartopy projection
ax = plt.axes(projection=ccrs.PlateCarree())
# and extent
ax.set_extent([min_lon, max_lon, min_lat, max_lat], ccrs.PlateCarree())

# Plotting using Matplotlib 
# We plot the Chl at -60m(k=5) at the final recorded time interval
cf = ds_bio11_clip.Chl_a_sum.isel(time=-1,k=5).plot( 
    transform=ccrs.PlateCarree(), cmap=color,
    vmin = 0, vmax = 1.4,
    add_colorbar=False
)

# Color bar
cbar = fig.colorbar(cf, ax=ax, fraction=0.027, pad=0.045, 
                    orientation="horizontal")
cbar.set_label(ds_bio11_clip.Chl_a_sum.long_name+' '+ds_bio11_clip.Chl_a_sum.units, rotation=0, 
               labelpad=5, fontsize=10)
cbar.ax.tick_params(labelsize=8)

# Title
plt.title('zc = '+str(ds_bio11_clip.zc.values.item(-1))+' m at '+
          str(ds_bio11_clip.coords['time'].values[-1])[:10],
          fontsize=11
         )

# Plot lat/lon grid 
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=0.1, color='k', alpha=1, 
                  linestyle='--')
gl.top_labels = False
gl.right_labels = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER
gl.xlabel_style = {'size': 8}
gl.ylabel_style = {'size': 8} 

# Add map features with Cartopy 
ax.add_feature(cfeature.NaturalEarthFeature('physical', 'land', '10m', 
                                            edgecolor='face', 
                                            facecolor='lightgray'))
ax.coastlines(linewidth=1)

# Site Davies Reef
ax.scatter(locA_lon, locA_lat, c='deeppink', s=70, edgecolors='k', 
           linewidth=1, transform=ccrs.PlateCarree())

plt.tight_layout()
plt.show()
